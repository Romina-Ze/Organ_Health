# %% [markdown]
# # PC1 / PCA Pipeline
#
# This notebook computes organ PC scores and protein loading summaries. The full code is in `src/pc1_pipeline.py`.

# %% [markdown]
# This step uses proteomics, protein-to-organ mapping, and age-gap outputs from the organ age model.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from pc1_pipeline import PC1Config, run_pipeline

# %%
config = PC1Config(
    input_dir=PROJECT_ROOT / "data" / "raw",
    output_dir=PROJECT_ROOT / "results" / "pc1",
    proteomics_file="N.proteomics_preprocessed.csv",
    mapping_file="1.final_merged_protein_organ.csv",
    age_gap_file="resid_Age_Gaps.csv",
)

# %%
outputs = run_pipeline(config)
outputs
