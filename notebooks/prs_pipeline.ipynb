# %% [markdown]
# # PRS Pipeline
#
# This notebook tests PRS associations with organ age-gap, PC1, and PLS metrics. The full code is in `src/prs_pipeline.py`.

# %% [markdown]
# The input should be a local merged table containing PRS columns, age, sex, and organ metrics. Do not commit this file.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from prs_pipeline import PRSConfig, run_pipeline

# %%
config = PRSConfig(
    input_file=PROJECT_ROOT / "data" / "raw" / "prs_agegap_pc1_pls.csv",
    output_dir=PROJECT_ROOT / "results" / "prs",
    age_col="Age",
    sex_col="Sex",
)

# %%
outputs = run_pipeline(config)
outputs
