# %% [markdown]
# # Diagnosis Pipeline
#
# Small wrapper around `src/diagnosis_pipeline.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from diagnosis_pipeline import DiagnosisConfig, run_pipeline

# %%
config = DiagnosisConfig(
    metadata_file=PROJECT_ROOT / "data" / "raw" / "metadata.csv",
    metrics_file=PROJECT_ROOT / "results" / "pc1" / "age_gaps_and_pcs.csv",
    output_dir=PROJECT_ROOT / "results" / "diagnosis",
    config_file=PROJECT_ROOT / "configs" / "diagnosis_icd10.json",
)
outputs = run_pipeline(config)
outputs
