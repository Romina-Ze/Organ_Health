# %% [markdown]
# # Organ Age Gap Pipeline
#
# This notebook runs the cleaned XGBoost organ age-gap code. The full code is in `src/organ_age_gap_pipeline.py`.

# %% [markdown]
# Expected local input files in `data/raw/`:
#
# - `1.final_merged_protein_organ.csv`
# - `N.merged_proteomics_mri.csv`
# - `N.proteomics_preprocessed.csv`

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from organ_age_gap_pipeline import PipelineConfig, QUICK_PARAM_GRID, run_pipeline

# %%
config = PipelineConfig(
    input_dir=PROJECT_ROOT / "data" / "raw",
    output_dir=PROJECT_ROOT / "results" / "organ_age",
)

# %%
outputs = run_pipeline(config, param_grid=QUICK_PARAM_GRID)
outputs
