# %% [markdown]
# # Organ Age Gap XGBoost Pipeline
#
# This notebook is a clean wrapper around the pipeline in `src/organ_age_gap_pipeline.py`. It does not contain UK Biobank data or saved outputs.

# %% [markdown]
# Before running this notebook, keep the real data locally under `data/raw/`. The `data/` and `results/` folders are ignored by Git.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from organ_age_gap_pipeline import PipelineConfig, QUICK_PARAM_GRID, run_pipeline

# %%
config = PipelineConfig(
    input_dir=PROJECT_ROOT / "data" / "raw",
    output_dir=PROJECT_ROOT / "results",
    mapping_file="1.final_merged_protein_organ.csv",
    merged_file="N.merged_proteomics_mri.csv",
    proteomics_file="N.proteomics_preprocessed.csv",
)

# %%
outputs = run_pipeline(config, param_grid=QUICK_PARAM_GRID)
outputs
