# %% [markdown]
# # Brain Structure Analysis
#
# This notebook runs the cleaned brain MRI structure association code. The full code is in `src/brain_structure_pipeline.py`.

# %% [markdown]
# Expected local input files in `data/raw/`:
#
# - `AgeGap_Mri.csv`
# - `PC1_Mri.csv`
# - `PLS_Mri.csv`
#
# Set any file path to `None` if you only want to run part of the analysis.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from brain_structure_pipeline import BrainStructureConfig, run_pipeline

# %%
DATA_DIR = PROJECT_ROOT / "data" / "raw"

agegap_file = DATA_DIR / "AgeGap_Mri.csv"
pc1_file = DATA_DIR / "PC1_Mri.csv"
pls_file = DATA_DIR / "PLS_Mri.csv"

config = BrainStructureConfig(
    output_dir=PROJECT_ROOT / "results" / "brain_structure",
)

# %%
outputs = run_pipeline(
    config,
    agegap_file=agegap_file,
    pc1_file=pc1_file,
    pls_file=pls_file,
)
outputs
