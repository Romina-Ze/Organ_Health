# %% [markdown]
# # PLS Pipeline
#
# This notebook runs organ PLS models from local proteomics and phenotype tables. The full code is in `src/pls_pipeline.py`.

# %% [markdown]
# Edit `configs/pls_organs.example.json` or make your own private config with your local phenotype file names and organ phenotype columns.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from pls_pipeline import PLSConfig, run_pipeline

# %%
config = PLSConfig(
    config_file=PROJECT_ROOT / "configs" / "pls_organs.example.json",
    output_dir=PROJECT_ROOT / "results" / "pls",
)

# %%
outputs = run_pipeline(config)
outputs
