# %% [markdown]
# # Mediation Pipeline
#
# This notebook runs bootstrap mediation analyses. The full code is in `src/mediation_pipeline.py`.

# %% [markdown]
# Mediation pathways are stored in `configs/mediation_pathways.json`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from mediation_pipeline import MediationConfig, run_pipeline

# %%
config = MediationConfig(
    input_file=PROJECT_ROOT / "data" / "raw" / "mediation_master.csv",
    output_dir=PROJECT_ROOT / "results" / "mediation",
    config_file=PROJECT_ROOT / "configs" / "mediation_pathways.json",
    n_boot=1000,
    run_serial=False,
)

# %%
outputs = run_pipeline(config)
outputs
