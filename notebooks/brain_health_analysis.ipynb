# %% [markdown]
# # Brain Health Analysis
#
# The standalone `Brain_health.ipynb` file provided for refactoring was empty, so there is no separate brain-health pipeline here yet.

# %% [markdown]
# Brain-related analyses are currently represented in the other pipelines:
#
# - Brain age gap from `src/organ_age_gap_pipeline.py`
# - Brain PC1 from `src/pc1_pipeline.py`
# - Brain PLS if configured in `configs/pls_organs.example.json` or a private PLS config
# - Brain-related diagnosis associations from `src/diagnosis_pipeline.py`
# - Brain mediation pathways from `src/mediation_pipeline.py` and `configs/mediation_pathways.json`

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
available_brain_related_files = [
    PROJECT_ROOT / "src" / "organ_age_gap_pipeline.py",
    PROJECT_ROOT / "src" / "pc1_pipeline.py",
    PROJECT_ROOT / "src" / "diagnosis_pipeline.py",
    PROJECT_ROOT / "src" / "mediation_pipeline.py",
    PROJECT_ROOT / "configs" / "mediation_pathways.json",
]
available_brain_related_files
